# %% [markdown]
# # **TeleMarketing Prediction Model Using Machine Learning Technique**

# %% [markdown]
# ### Dataset Information and Science Direct Research Paper Link : https://archive.ics.uci.edu/dataset/222/bank+marketing

# %%
# Import Data Manimpulation Library
import numpy as np
import pandas as pd
# Import Data Visualization Library
import matplotlib.pyplot as plt
import seaborn as sns
# Import FilterWarning Library
import warnings
warnings.filterwarnings('ignore')
# Import Sci-Kit Learn Libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# # **Data Uploading**

# %%
url = 'https://raw.githubusercontent.com/chandanc5525/MachineLearning-Bootcamp/refs/heads/main/bank-additional-full.csv'

df = pd.read_csv(url,sep = ';')   # Important Step
df.sample(frac = 1)   # Shuffle Dataset
# Out:
#        age         job   marital            education default  housing  \
# 18033   38      admin.    single    university.degree      no      yes
# 28271   61     retired   married    university.degree      no      yes
# 27917   28      admin.    single          high.school      no      yes
# 10603   52    services   married          high.school      no      yes
# 6985    33    services   married    university.degree      no  unknown
# ...    ...         ...       ...                  ...     ...      ...
# 13991   33  technician    single    university.degree      no       no
# 22823   42  technician  divorced  professional.course      no      yes
# 19366   31  technician    single  professional.course      no      yes
# 39308   28      admin.    single    university.degree      no      yes
# 40616   22      admin.    single    university.degree      no      yes
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 18033       no   cellular   jul         wed  ...         1    999         0
# 28271       no   cellular   apr         wed  ...         2    999         0
# 27917       no  telephone   mar         fri  ...         1    999         0
# 10603       no  telephone   jun         tue  ...         2    999         0
# 6985   unknown  telephone   may         thu  ...         1    999         0
# ...        ...        ...   ...         ...  ...       ...    ...       ...
# 13991       no   cellular   jul         fri  ...         2    999         0
# 22823       no   cellular   aug         mon  ...         2    999         0
# 19366       no  telephone   aug         wed  ...         3    999         0
# 39308       no   cellular   mar         thu  ...         1      9         1
# 40616       no   cellular   sep         mon  ...         2    999         3
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 18033  nonexistent          1.4          93.918          -42.7      4.963
# 28271  nonexistent         -1.8          93.075          -47.1      1.445
# 27917  nonexistent         -1.8          92.843          -50.0      1.531
# 10603  nonexistent          1.4          94.465          -41.8      4.961
# 6985   nonexistent          1.1          93.994          -36.4      4.860
# ...            ...          ...             ...            ...        ...
# 13991  nonexistent          1.4          93.918          -42.7      4.963
# 22823  nonexistent          1.4          93.444          -36.1      4.965
# 19366  nonexistent          1.4          93.444          -36.1      4.967
# 39308      success         -1.8          93.369          -34.8      0.643
# 40616      failure         -1.1          94.199          -37.5      0.882
#
#        nr.employed    y
# 18033       5228.1   no
# 28271       5099.1   no
# 27917       5099.1  yes
# 10603       5228.1   no
# 6985        5191.0   no
# ...            ...  ...
# 13991       5228.1   no
# 22823       5228.1   no
# 19366       5228.1   no
# 39308       5008.7   no
# 40616       4963.6  yes
#
# [41188 rows x 21 columns]

# %% [markdown]
# # **Data Attributes**

# %% [markdown]
# ## **Bank Client Data:**
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
#
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
#
# 4 - education (categorical: 'basic.4y',' basic.6y',' basic.9y', 'high.school', 'illiterate', 'professional.course', 'university.degree', 'unknown')
#
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
#
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
#
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown') -- related with the last contact of the current campaign
#
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
#
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', …, 'nov', 'dec')
#
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
#
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# ## **Other attributes:**
#
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# ## **Social and economic context attributes:**
#
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
#
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
#
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
#
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# ## **Output variable (desired target):**
#
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %%
# Chekcing Information about Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
# By Visualization Checking if any null value present or not
plt.figure(figsize = (10,5))
sns.heatmap(df.isnull(),cmap='coolwarm',center = 0,yticklabels=False)
plt.show()

# %%
# Checking Dataset:
df.sample(5)
# Out:
#        age         job   marital    education  default housing loan  \
# 34878   32      admin.    single  high.school       no      no   no
# 5675    59     retired   married      unknown  unknown      no   no
# 13060   40    services  divorced  high.school       no     yes   no
# 7268    32    services   married  high.school  unknown     yes  yes
# 21864   29  technician    single  high.school  unknown     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 34878   cellular   may         fri  ...         9    999         0
# 5675   telephone   may         mon  ...         1    999         0
# 13060   cellular   jul         tue  ...         2    999         0
# 7268   telephone   may         thu  ...         3    999         0
# 21864   cellular   aug         wed  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 34878  nonexistent         -1.8          92.893          -46.2      1.250
# 5675   nonexistent          1.1          93.994          -36.4      4.857
# 13060  nonexistent          1.4          93.918          -42.7      4.962
# 7268   nonexistent          1.1          93.994          -36.4      4.860
# 21864  nonexistent          1.4          93.444          -36.1      4.964
#
#        nr.employed   y
# 34878       5099.1  no
# 5675        5191.0  no
# 13060       5228.1  no
# 7268        5191.0  no
# 21864       5228.1  no
#
# [5 rows x 21 columns]

# %%
# Divide Dataset into Categorical and Numerical:

numerical_data = df.select_dtypes(exclude = 'object')
categorical_data = df.select_dtypes(include = 'object')

# %%
categorical_data.sample(5)
# Out:
#                job   marital            education  default housing loan  \
# 34437      student    single          high.school       no     yes   no
# 12545       admin.    single    university.degree  unknown      no   no
# 24928  blue-collar  divorced              unknown       no      no   no
# 17633       admin.   married    university.degree       no     yes  yes
# 40878   technician   married  professional.course       no      no   no
#
#         contact month day_of_week     poutcome    y
# 34437  cellular   may         thu  nonexistent   no
# 12545  cellular   jul         mon  nonexistent   no
# 24928  cellular   nov         tue  nonexistent  yes
# 17633  cellular   jul         mon  nonexistent   no
# 40878  cellular   oct         wed      failure   no

# %%
numerical_data.sample(5)
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 5005    28       165         2    999         0           1.1          93.994
# 265     27       350         1    999         0           1.1          93.994
# 21462   38        74         1    999         0           1.4          93.444
# 13254   34       337         1    999         0           1.4          93.918
# 33198   58       451         2    999         1          -1.8          92.893
#
#        cons.conf.idx  euribor3m  nr.employed
# 5005           -36.4      4.858       5191.0
# 265            -36.4      4.857       5191.0
# 21462          -36.1      4.963       5228.1
# 13254          -42.7      4.962       5228.1
# 33198          -46.2      1.291       5099.1

# %%
plt.figure(figsize = (10,15))
plt.tight_layout()
plot = 0

for i in numerical_data.columns:
  plot = plot + 1
  plt.subplot(5,2,plot)
  sns.boxenplot(df[i])
plt.show()

# %%
for i in categorical_data.columns:
    print(categorical_data[i].value_counts())
    print('*'*20)
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64
# ********************
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64
# ********************
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64
# ********************
# default
# no         32588
# unknown     8597
# yes            3
# Name: count, dtype: int64
# ********************
# housing
# yes        21576
# no         18622
# unknown      990
# Name: count, dtype: int64
# ********************
# loan
# no         33950
# yes         6248
# unknown      990
# Name: count, dtype: int64
# ********************
# contact
# cellular     26144
# telephone    15044
# Name: count, dtype: int64
# ********************
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64
# ********************
# day_of_week
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: count, dtype: int64
# ********************
# poutcome
# nonexistent    35563
# failure         4252
# success         1373
# Name: count, dtype: int64
# ********************
# y
# no     36548
# yes     4640
# Name: count, dtype: int64
# ********************

# %%
df['y'].replace({'yes':1,'no':0},inplace = True)

# %%
categorical_data.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
df['job'] = LabelEncoder().fit_transform(df['job'])
df['marital'] = LabelEncoder().fit_transform(df['marital'])
df['education'] = LabelEncoder().fit_transform(df['education'])
df['default'] = LabelEncoder().fit_transform(df['default'])
df['housing'] = LabelEncoder().fit_transform(df['housing'])
df['loan'] = LabelEncoder().fit_transform(df['loan'])
df['contact'] = LabelEncoder().fit_transform(df['contact'])
df['month'] = LabelEncoder().fit_transform(df['month'])
df['day_of_week'] = LabelEncoder().fit_transform(df['day_of_week'])
df['poutcome'] = LabelEncoder().fit_transform(df['poutcome'])

# %%
df.sample(5)
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 27900   36    4        1          6        0        2     0        0      5
# 12184   47    1        0          2        0        0     0        1      3
# 31941   28    7        1          2        1        0     0        1      6
# 5933    36    2        1          6        1        0     0        1      6
# 18021   49    0        0          2        0        2     0        0      3
#
#        day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 27900            2  ...         1    999         1         0          -1.8
# 12184            3  ...         1    999         0         1           1.4
# 31941            2  ...         2    999         0         1          -1.8
# 5933             3  ...         2    999         0         1           1.1
# 18021            4  ...         1    999         0         1           1.4
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 27900          92.843          -50.0      1.538       5099.1  0
# 12184          93.918          -42.7      4.955       5228.1  0
# 31941          92.893          -46.2      1.327       5099.1  0
# 5933           93.994          -36.4      4.857       5191.0  0
# 18021          93.918          -42.7      4.963       5228.1  0
#
# [5 rows x 21 columns]

# %%
df['y'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='y'>

# %%
# Split the Dataset into Train and Test
X = df.drop(columns = ['y'], axis = 1)
y = df['y']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,
                                                 random_state = 42)

# %%
# Use Scaling Technique
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.max(),X_train.min()
# Out:
# (1.0, 0.0)

# %%
# Use Balance Dataset Technique
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state = 42)
X_train,y_train = smote.fit_resample(X_train,y_train)

# %% [markdown]
# # **Random Forest Prediction Model**

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train,y_train)
y_pred_rf = rf_model.predict(X_test)

print(accuracy_score(y_test,y_pred_rf))
# Out:
# 0.9063688597556041

# %%
X.shape
# Out:
# (41188, 20)

# %% [markdown]
# # **ANN Model Building**

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense

# %%
ann_model = Sequential()

ann_model.add(Dense(128,activation = 'relu',input_dim = 20))
ann_model.add(Dense(64,activation = 'relu'))
ann_model.add(Dense(32,activation = 'relu'))
ann_model.add(Dense(16,activation = 'relu'))
ann_model.add(Dense(1,activation = 'sigmoid'))

# %%
ann_model.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
ann_model.fit(X_train,y_train,epochs = 100,batch_size = 32,
              validation_split = 0.3)
# Out:
# Epoch 1/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8169 - loss: 0.4038 - val_accuracy: 0.8077 - val_loss: 0.5261
# Epoch 2/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8725 - loss: 0.2889 - val_accuracy: 0.8834 - val_loss: 0.3522
# Epoch 3/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8771 - loss: 0.2763 - val_accuracy: 0.8294 - val_loss: 0.4889
# Epoch 4/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8786 - loss: 0.2655 - val_accuracy: 0.7007 - val_loss: 0.6386
# Epoch 5/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8859 - loss: 0.2535 - val_accuracy: 0.9141 - val_loss: 0.3483
# Epoch 6/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8869 - loss: 0.2498 - val_accuracy: 0.9105 - val_loss: 0.3193
# Epoch 7/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8865 - loss: 0.2486 - val_accuracy: 0.8969 - val_loss: 0.3274
# Epoch 8/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8905 - loss: 0.2422 - val_accuracy: 0.9100 - val_loss: 0.3627
# Epoch 9/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8895 - loss: 0.2426 - val_accuracy: 0.8438 - val_loss: 0.4280
# Epoch 10/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8925 - loss: 0.2364 - val_accuracy: 0.8821 - val_loss: 0.3768
# Epoch 11/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8963 - loss: 0.2320 - val_accuracy: 0.9244 - val_loss: 0.3200
# Epoch 12/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8937 - loss: 0.2328 - val_accuracy: 0.9045 - val_loss: 0.3180
# Epoch 13/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8979 - loss: 0.2293 - val_accuracy: 0.8798 - val_loss: 0.3688
# Epoch 14/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9018 - loss: 0.2255 - val_accuracy: 0.9069 - val_loss: 0.3303
# Epoch 15/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9017 - loss: 0.2212 - val_accuracy: 0.9113 - val_loss: 0.3308
# Epoch 16/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9022 - loss: 0.2233 - val_accuracy: 0.9307 - val_loss: 0.2697
# Epoch 17/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9032 - loss: 0.2180 - val_accuracy: 0.9102 - val_loss: 0.2929
# Epoch 18/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9087 - loss: 0.2094 - val_accuracy: 0.9212 - val_loss: 0.2940
# Epoch 19/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9075 - loss: 0.2082 - val_accuracy: 0.9250 - val_loss: 0.2830
# Epoch 20/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9098 - loss: 0.2056 - val_accuracy: 0.9292 - val_loss: 0.2575
# Epoch 21/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9114 - loss: 0.1987 - val_accuracy: 0.9242 - val_loss: 0.2727
# Epoch 22/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9094 - loss: 0.2032 - val_accuracy: 0.9393 - val_loss: 0.2401
# Epoch 23/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9145 - loss: 0.1937 - val_accuracy: 0.9044 - val_loss: 0.3020
# Epoch 24/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9171 - loss: 0.1913 - val_accuracy: 0.9187 - val_loss: 0.2739
# Epoch 25/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9177 - loss: 0.1895 - val_accuracy: 0.9029 - val_loss: 0.2938
# Epoch 26/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9167 - loss: 0.1879 - val_accuracy: 0.9031 - val_loss: 0.3129
# Epoch 27/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9183 - loss: 0.1887 - val_accuracy: 0.8727 - val_loss: 0.3376
# Epoch 28/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9214 - loss: 0.1843 - val_accuracy: 0.8593 - val_loss: 0.3693
# Epoch 29/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9238 - loss: 0.1782 - val_accuracy: 0.9096 - val_loss: 0.2970
# Epoch 30/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9248 - loss: 0.1758 - val_accuracy: 0.9591 - val_loss: 0.1884
# Epoch 31/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9255 - loss: 0.1726 - val_accuracy: 0.8771 - val_loss: 0.3236
# Epoch 32/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9296 - loss: 0.1674 - val_accuracy: 0.9363 - val_loss: 0.2194
# Epoch 33/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9293 - loss: 0.1684 - val_accuracy: 0.9380 - val_loss: 0.2201
# Epoch 34/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9324 - loss: 0.1648 - val_accuracy: 0.9297 - val_loss: 0.2327
# Epoch 35/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9308 - loss: 0.1632 - val_accuracy: 0.9324 - val_loss: 0.2137
# Epoch 36/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9339 - loss: 0.1582 - val_accuracy: 0.8343 - val_loss: 0.4078
# Epoch 37/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9311 - loss: 0.1628 - val_accuracy: 0.9361 - val_loss: 0.2114
# Epoch 38/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9339 - loss: 0.1546 - val_accuracy: 0.9216 - val_loss: 0.2272
# Epoch 39/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9321 - loss: 0.1591 - val_accuracy: 0.9201 - val_loss: 0.2358
# Epoch 40/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9389 - loss: 0.1466 - val_accuracy: 0.9342 - val_loss: 0.2173
# Epoch 41/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9391 - loss: 0.1465 - val_accuracy: 0.9237 - val_loss: 0.2279
# Epoch 42/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9400 - loss: 0.1470 - val_accuracy: 0.9285 - val_loss: 0.2133
# Epoch 43/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9410 - loss: 0.1413 - val_accuracy: 0.9179 - val_loss: 0.2377
# Epoch 44/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9391 - loss: 0.1434 - val_accuracy: 0.9573 - val_loss: 0.1554
# Epoch 45/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9423 - loss: 0.1396 - val_accuracy: 0.9053 - val_loss: 0.2573
# Epoch 46/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9430 - loss: 0.1387 - val_accuracy: 0.9553 - val_loss: 0.1589
# Epoch 47/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9450 - loss: 0.1338 - val_accuracy: 0.9199 - val_loss: 0.2384
# Epoch 48/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9476 - loss: 0.1296 - val_accuracy: 0.9445 - val_loss: 0.1829
# Epoch 49/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9468 - loss: 0.1299 - val_accuracy: 0.9315 - val_loss: 0.2060
# Epoch 50/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9485 - loss: 0.1264 - val_accuracy: 0.9021 - val_loss: 0.2610
# Epoch 51/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9506 - loss: 0.1224 - val_accuracy: 0.8672 - val_loss: 0.3292
# Epoch 52/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9471 - loss: 0.1286 - val_accuracy: 0.9455 - val_loss: 0.1786
# Epoch 53/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9509 - loss: 0.1223 - val_accuracy: 0.9111 - val_loss: 0.2437
# Epoch 54/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9517 - loss: 0.1194 - val_accuracy: 0.9302 - val_loss: 0.1935
# Epoch 55/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9537 - loss: 0.1162 - val_accuracy: 0.9361 - val_loss: 0.1911
# Epoch 56/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9552 - loss: 0.1125 - val_accuracy: 0.9143 - val_loss: 0.2396
# Epoch 57/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9544 - loss: 0.1173 - val_accuracy: 0.9594 - val_loss: 0.1371
# Epoch 58/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9542 - loss: 0.1126 - val_accuracy: 0.9263 - val_loss: 0.2054
# Epoch 59/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9542 - loss: 0.1118 - val_accuracy: 0.9472 - val_loss: 0.1686
# Epoch 60/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9539 - loss: 0.1130 - val_accuracy: 0.9515 - val_loss: 0.1619
# Epoch 61/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9570 - loss: 0.1086 - val_accuracy: 0.9236 - val_loss: 0.2181
# Epoch 62/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9575 - loss: 0.1080 - val_accuracy: 0.9658 - val_loss: 0.1213
# Epoch 63/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9562 - loss: 0.1130 - val_accuracy: 0.9481 - val_loss: 0.1574
# Epoch 64/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9592 - loss: 0.1051 - val_accuracy: 0.9274 - val_loss: 0.2061
# Epoch 65/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9591 - loss: 0.1040 - val_accuracy: 0.9419 - val_loss: 0.1695
# Epoch 66/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9593 - loss: 0.0994 - val_accuracy: 0.9640 - val_loss: 0.1272
# Epoch 67/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9605 - loss: 0.0994 - val_accuracy: 0.9498 - val_loss: 0.1500
# Epoch 68/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9605 - loss: 0.0999 - val_accuracy: 0.9229 - val_loss: 0.2305
# Epoch 69/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9634 - loss: 0.0938 - val_accuracy: 0.9520 - val_loss: 0.1455
# Epoch 70/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9626 - loss: 0.0942 - val_accuracy: 0.9208 - val_loss: 0.2304
# Epoch 71/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9631 - loss: 0.0940 - val_accuracy: 0.9440 - val_loss: 0.1629
# Epoch 72/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9634 - loss: 0.0956 - val_accuracy: 0.9547 - val_loss: 0.1395
# Epoch 73/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9630 - loss: 0.0914 - val_accuracy: 0.9131 - val_loss: 0.2456
# Epoch 74/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9658 - loss: 0.0877 - val_accuracy: 0.9502 - val_loss: 0.1509
# Epoch 75/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9627 - loss: 0.0965 - val_accuracy: 0.9406 - val_loss: 0.1768
# Epoch 76/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9665 - loss: 0.0869 - val_accuracy: 0.9539 - val_loss: 0.1417
# Epoch 77/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9660 - loss: 0.0849 - val_accuracy: 0.9421 - val_loss: 0.1734
# Epoch 78/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9664 - loss: 0.0864 - val_accuracy: 0.9344 - val_loss: 0.1798
# Epoch 79/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9642 - loss: 0.0890 - val_accuracy: 0.9562 - val_loss: 0.1332
# Epoch 80/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9627 - loss: 0.0926 - val_accuracy: 0.9395 - val_loss: 0.1792
# Epoch 81/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9656 - loss: 0.0883 - val_accuracy: 0.9339 - val_loss: 0.1839
# Epoch 82/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9679 - loss: 0.0838 - val_accuracy: 0.9277 - val_loss: 0.1948
# Epoch 83/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9651 - loss: 0.0878 - val_accuracy: 0.9598 - val_loss: 0.1220
# Epoch 84/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9691 - loss: 0.0780 - val_accuracy: 0.9564 - val_loss: 0.1350
# Epoch 85/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9686 - loss: 0.0786 - val_accuracy: 0.9599 - val_loss: 0.1208
# Epoch 86/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9679 - loss: 0.0818 - val_accuracy: 0.9260 - val_loss: 0.2112
# Epoch 87/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9679 - loss: 0.0786 - val_accuracy: 0.9717 - val_loss: 0.1056
# Epoch 88/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9680 - loss: 0.0803 - val_accuracy: 0.9582 - val_loss: 0.1416
# Epoch 89/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9688 - loss: 0.0782 - val_accuracy: 0.9203 - val_loss: 0.2145
# Epoch 90/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9693 - loss: 0.0782 - val_accuracy: 0.9455 - val_loss: 0.1608
# Epoch 91/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9701 - loss: 0.0737 - val_accuracy: 0.9460 - val_loss: 0.1583
# Epoch 92/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9691 - loss: 0.0783 - val_accuracy: 0.9421 - val_loss: 0.1653
# Epoch 93/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9711 - loss: 0.0726 - val_accuracy: 0.9429 - val_loss: 0.1574
# Epoch 94/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9703 - loss: 0.0740 - val_accuracy: 0.9376 - val_loss: 0.1708
# Epoch 95/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9697 - loss: 0.0791 - val_accuracy: 0.9289 - val_loss: 0.2009
# Epoch 96/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9715 - loss: 0.0725 - val_accuracy: 0.9439 - val_loss: 0.1590
# Epoch 97/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9718 - loss: 0.0710 - val_accuracy: 0.9499 - val_loss: 0.1516
# Epoch 98/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9747 - loss: 0.0680 - val_accuracy: 0.9459 - val_loss: 0.1612
# Epoch 99/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9723 - loss: 0.0737 - val_accuracy: 0.9174 - val_loss: 0.2198
# Epoch 100/100
# 1120/1120 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9716 - loss: 0.0701 - val_accuracy: 0.9556 - val_loss: 0.1324

# %%
model_history = ann_model.history.history

plt.figure(figsize = (10,5))
plt.plot(model_history['accuracy'])
plt.plot(model_history['loss'])
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Epoch')
plt.legend(['Accuracy','Loss'],loc = 'upper left')
plt.show()

# %%
y_pred_ann = ann_model.predict(X_test)
y_pred_ann = np.where(y_pred_ann > 0.5,1,0)
print('Accuracy Score :',accuracy_score(y_test,y_pred_ann))
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy Score : 0.8866229667394999

# %%
from sklearn.metrics import roc_curve,roc_auc_score

fpr,tpr,thresholds = roc_curve(y_test,y_pred_ann)
plt.plot(fpr,tpr)
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
